# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 715

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']        
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloudiness = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_desc = city_weather['weather'][0]['description']
                
        # Append the city information into the city_data list
        city_data.append({'City' : city.title(),
                          'Lat' : city_lat,
                          'Lng' : city_lng,
                          'Max Temp' : city_max_temp,
                          'Humidity' : city_humidity,
                          'Cloudiness' : city_cloudiness,
                          'Wind Speed' : city_wind,
                          'Country' : city_country,
                          'Current Description' : city_weather_desc})
                         
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mnogovershinnyy
# Processing Record 2 of Set 1 | luderitz
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | cartersville
# Processing Record 14 of Set 1 | casino
# Processing Record 15 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 1 | tabou
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | kailua
# Processing Record 19 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 1 | det udom
# Processing Record 21 of Set 1 | alekseyevka
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | iquitos
# Processing Record 25 of Set 1 | lingyuan
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | dir
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | sann
# Processing Record 30 of Set 1 | souillac
# Processing Record 31 of Set 1 | ahipara
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | kudahuvadhoo
# Processing Record 34 of Set 1 | boa vista
# Processing Record 35 of Set 1 | atambua
# Processing Record 36 of Set 1 | jaque
# Processing Record 37 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | talaya
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | winsum
# Processing Record 43 of Set 1 | yatou
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | bintulu
# Processing Record 46 of Set 1 | jijiga
# Processing Record 47 of Set 1 | nelson bay
# Processing Record 48 of Set 1 | portland
# Processing Record 49 of Set 1 | lorengau
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | puerto pinasco
# City not found. Skipping...
# Processing Record 3 of Set 2 | rawson
# Processing Record 4 of Set 2 | pacific grove
# Processing Record 5 of Set 2 | perth
# Processing Record 6 of Set 2 | thinadhoo
# Processing Record 7 of Set 2 | port blair
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | ziro
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | marsh harbour
# Processing Record 14 of Set 2 | mahebourg
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | aykhal
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | porrentruy
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | riyadh
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | aasiaat
# Processing Record 29 of Set 2 | chapais
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | lubao
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | vestmannaeyjar
# Processing Record 34 of Set 2 | kashary
# Processing Record 35 of Set 2 | takoradi
# Processing Record 36 of Set 2 | guadalupe y calvo
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | longyearbyen
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | hualmay
# Processing Record 42 of Set 2 | acapulco
# Processing Record 43 of Set 2 | yilan
# Processing Record 44 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 45 of Set 2 | taicheng
# Processing Record 46 of Set 2 | usinsk
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | barabinsk
# Processing Record 49 of Set 2 | ialibu
# Processing Record 50 of Set 2 | channel-port aux basques
# Processing Record 1 of Set 3 | quatre cocos
# Processing Record 2 of Set 3 | emba
# Processing Record 3 of Set 3 | miri
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | flinders
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | olafsvik
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | bakchar
# Processing Record 10 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 3 | picayune
# Processing Record 12 of Set 3 | la paz
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | nouadhibou
# Processing Record 16 of Set 3 | pirovskoye
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | nicoya
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | vao
# Processing Record 23 of Set 3 | tuktoyaktuk
# Processing Record 24 of Set 3 | hay river
# Processing Record 25 of Set 3 | raga
# Processing Record 26 of Set 3 | griffith
# Processing Record 27 of Set 3 | el alto
# Processing Record 28 of Set 3 | saint-francois
# Processing Record 29 of Set 3 | natal
# Processing Record 30 of Set 3 | kendari
# Processing Record 31 of Set 3 | doha
# Processing Record 32 of Set 3 | tommot
# Processing Record 33 of Set 3 | zalantun
# Processing Record 34 of Set 3 | pierre
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | shache
# Processing Record 37 of Set 3 | kismayo
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 3 | nuevitas
# Processing Record 43 of Set 3 | whitehorse
# Processing Record 44 of Set 3 | alice springs
# Processing Record 45 of Set 3 | puerto colombia
# Processing Record 46 of Set 3 | kerewan
# Processing Record 47 of Set 3 | namatanai
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 3 | oranjemund
# Processing Record 1 of Set 4 | alta floresta
# Processing Record 2 of Set 4 | north bend
# Processing Record 3 of Set 4 | ambon
# Processing Record 4 of Set 4 | mackay
# Processing Record 5 of Set 4 | svetlaya
# Processing Record 6 of Set 4 | komsomolskiy
# Processing Record 7 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | vanimo
# Processing Record 10 of Set 4 | ximei
# Processing Record 11 of Set 4 | ulladulla
# Processing Record 12 of Set 4 | tabuk
# Processing Record 13 of Set 4 | kavaratti
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | los llanos de aridane
# Processing Record 16 of Set 4 | port moresby
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | road town
# Processing Record 19 of Set 4 | jamestown
# Processing Record 20 of Set 4 | juneau
# Processing Record 21 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | papar
# Processing Record 24 of Set 4 | honningsvag
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | bontang
# Processing Record 27 of Set 4 | canutama
# Processing Record 28 of Set 4 | halifax
# Processing Record 29 of Set 4 | xuddur
# Processing Record 30 of Set 4 | oussouye
# Processing Record 31 of Set 4 | carutapera
# Processing Record 32 of Set 4 | sturgeon bay
# Processing Record 33 of Set 4 | ribeira grande
# Processing Record 34 of Set 4 | nikolskoye
# Processing Record 35 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 4 | matay
# Processing Record 37 of Set 4 | dikson
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | fuxin
# Processing Record 40 of Set 4 | french harbor
# Processing Record 41 of Set 4 | sao filipe
# Processing Record 42 of Set 4 | klaksvik
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | charagua
# Processing Record 48 of Set 4 | iralaya
# Processing Record 49 of Set 4 | villa bruzual
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | te anau
# Processing Record 4 of Set 5 | sao jose da coroa grande
# Processing Record 5 of Set 5 | vanavara
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | alakurtti
# Processing Record 8 of Set 5 | mecayapan
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | mayumba
# Processing Record 11 of Set 5 | xining
# Processing Record 12 of Set 5 | flin flon
# Processing Record 13 of Set 5 | pundaguitan
# Processing Record 14 of Set 5 | eschwege
# Processing Record 15 of Set 5 | srednekolymsk
# Processing Record 16 of Set 5 | walvis bay
# Processing Record 17 of Set 5 | kumluca
# Processing Record 18 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 5 | ingham
# Processing Record 20 of Set 5 | san jose
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | fallon
# Processing Record 23 of Set 5 | amahai
# Processing Record 24 of Set 5 | waingapu
# Processing Record 25 of Set 5 | teknaf
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | japura
# Processing Record 28 of Set 5 | lata
# Processing Record 29 of Set 5 | yumen
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | chernyshevskiy
# Processing Record 32 of Set 5 | hamilton
# Processing Record 33 of Set 5 | maceio
# Processing Record 34 of Set 5 | hithadhoo
# Processing Record 35 of Set 5 | keskin
# Processing Record 36 of Set 5 | umm kaddadah
# Processing Record 37 of Set 5 | altay
# Processing Record 38 of Set 5 | waipawa
# Processing Record 39 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 40 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 5 | shimoda
# Processing Record 42 of Set 5 | pokhara
# Processing Record 43 of Set 5 | pangnirtung
# Processing Record 44 of Set 5 | mar del plata
# Processing Record 45 of Set 5 | avera
# Processing Record 46 of Set 5 | bilma
# Processing Record 47 of Set 5 | dalhousie
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 5 | jumla
# Processing Record 1 of Set 6 | rio gallegos
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | praia da vitoria
# Processing Record 4 of Set 6 | christchurch
# Processing Record 5 of Set 6 | sinjar
# Processing Record 6 of Set 6 | norman wells
# Processing Record 7 of Set 6 | san matias
# Processing Record 8 of Set 6 | alugan
# Processing Record 9 of Set 6 | san cristobal
# Processing Record 10 of Set 6 | bol
# Processing Record 11 of Set 6 | muroto
# Processing Record 12 of Set 6 | sept-iles
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | oskarshamn
# Processing Record 15 of Set 6 | emerald
# Processing Record 16 of Set 6 | quthing
# Processing Record 17 of Set 6 | zhuanghe
# Processing Record 18 of Set 6 | fare
# Processing Record 19 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 6 | reims
# Processing Record 21 of Set 6 | bathsheba
# Processing Record 22 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 6 | ayan
# Processing Record 24 of Set 6 | waterloo
# Processing Record 25 of Set 6 | torres
# Processing Record 26 of Set 6 | hervey bay
# Processing Record 27 of Set 6 | carnarvon
# Processing Record 28 of Set 6 | islamkot
# Processing Record 29 of Set 6 | wilmington
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | huarmey
# Processing Record 32 of Set 6 | winnemucca
# Processing Record 33 of Set 6 | mbini
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | wanaka
# Processing Record 36 of Set 6 | buala
# Processing Record 37 of Set 6 | baturaja
# Processing Record 38 of Set 6 | stornoway
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | asau
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | madang
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | bom sucesso
# Processing Record 45 of Set 6 | smithers
# Processing Record 46 of Set 6 | wolfen
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | stawell
# Processing Record 49 of Set 6 | brae
# Processing Record 50 of Set 6 | zvishavane
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | xilitla
# Processing Record 3 of Set 7 | half moon bay
# Processing Record 4 of Set 7 | snezhnogorsk
# Processing Record 5 of Set 7 | urengoy
# Processing Record 6 of Set 7 | nampula
# Processing Record 7 of Set 7 | seydi
# Processing Record 8 of Set 7 | havre-saint-pierre
# Processing Record 9 of Set 7 | nauchnyy gorodok
# Processing Record 10 of Set 7 | hazorasp
# Processing Record 11 of Set 7 | chama
# Processing Record 12 of Set 7 | cairns
# Processing Record 13 of Set 7 | fort smith
# Processing Record 14 of Set 7 | rio cuarto
# Processing Record 15 of Set 7 | fort beaufort
# Processing Record 16 of Set 7 | launceston
# Processing Record 17 of Set 7 | odweyne
# Processing Record 18 of Set 7 | manokwari
# Processing Record 19 of Set 7 | merauke
# Processing Record 20 of Set 7 | dinghai
# Processing Record 21 of Set 7 | broken hill
# Processing Record 22 of Set 7 | auki
# Processing Record 23 of Set 7 | zhangjiakou
# Processing Record 24 of Set 7 | makakilo city
# Processing Record 25 of Set 7 | verkhoyansk
# Processing Record 26 of Set 7 | tarakan
# Processing Record 27 of Set 7 | san luis
# Processing Record 28 of Set 7 | hofn
# Processing Record 29 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 7 | mangrol
# Processing Record 31 of Set 7 | gorom-gorom
# Processing Record 32 of Set 7 | carballo
# Processing Record 33 of Set 7 | rivadavia
# Processing Record 34 of Set 7 | cap malheureux
# Processing Record 35 of Set 7 | hamina
# Processing Record 36 of Set 7 | puerto leguizamo
# Processing Record 37 of Set 7 | epe
# Processing Record 38 of Set 7 | nalut
# Processing Record 39 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 7 | marystown
# Processing Record 41 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | biu
# Processing Record 44 of Set 7 | lakhisarai
# Processing Record 45 of Set 7 | waddan
# Processing Record 46 of Set 7 | darfield
# Processing Record 47 of Set 7 | bubaque
# Processing Record 48 of Set 7 | tahta
# Processing Record 49 of Set 7 | konza
# Processing Record 50 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 8 | mae ramat
# Processing Record 2 of Set 8 | zyryanka
# Processing Record 3 of Set 8 | storsteinnes
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | mackenzie
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | townsville
# Processing Record 8 of Set 8 | coquimbo
# Processing Record 9 of Set 8 | saint-paul
# Processing Record 10 of Set 8 | leshan
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | laguna
# Processing Record 13 of Set 8 | bridgewater
# Processing Record 14 of Set 8 | yakeshi
# Processing Record 15 of Set 8 | burica
# City not found. Skipping...
# Processing Record 16 of Set 8 | barma
# Processing Record 17 of Set 8 | ranong
# Processing Record 18 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 8 | del city
# Processing Record 20 of Set 8 | carmen
# Processing Record 21 of Set 8 | mengcheng
# Processing Record 22 of Set 8 | point fortin
# Processing Record 23 of Set 8 | vadodara
# Processing Record 24 of Set 8 | lavrentiya
# Processing Record 25 of Set 8 | moissac
# Processing Record 26 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 8 | ciudad bolivar
# Processing Record 28 of Set 8 | aljezur
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | buribay
# Processing Record 31 of Set 8 | atasu
# Processing Record 32 of Set 8 | plettenberg bay
# Processing Record 33 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 8 | stepnogorsk
# Processing Record 35 of Set 8 | huilong
# Processing Record 36 of Set 8 | kikwit
# Processing Record 37 of Set 8 | severo-yeniseyskiy
# Processing Record 38 of Set 8 | wajid
# Processing Record 39 of Set 8 | ossora
# Processing Record 40 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 41 of Set 8 | green river
# Processing Record 42 of Set 8 | mount isa
# Processing Record 43 of Set 8 | benghazi
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | tasiilaq
# Processing Record 46 of Set 8 | huesca
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | leningradskiy
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 50 of Set 8 | teya
# Processing Record 1 of Set 9 | teguise
# Processing Record 2 of Set 9 | kloulklubed
# Processing Record 3 of Set 9 | mujiayingzi
# Processing Record 4 of Set 9 | mandalgovi
# Processing Record 5 of Set 9 | grand forks
# Processing Record 6 of Set 9 | college
# Processing Record 7 of Set 9 | torbay
# Processing Record 8 of Set 9 | okitipupa
# Processing Record 9 of Set 9 | santa cruz de tenerife
# Processing Record 10 of Set 9 | tsiroanomandidy
# Processing Record 11 of Set 9 | le port
# Processing Record 12 of Set 9 | mapimi
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | grindavik
# Processing Record 15 of Set 9 | marondera
# Processing Record 16 of Set 9 | bima
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | okha
# Processing Record 19 of Set 9 | garissa
# Processing Record 20 of Set 9 | hastings
# Processing Record 21 of Set 9 | kahului
# Processing Record 22 of Set 9 | oktyabrskoye
# Processing Record 23 of Set 9 | aksarka
# Processing Record 24 of Set 9 | ridgecrest
# Processing Record 25 of Set 9 | ouadda
# Processing Record 26 of Set 9 | anamur
# Processing Record 27 of Set 9 | tuatapere
# Processing Record 28 of Set 9 | yar-sale
# Processing Record 29 of Set 9 | kaitangata
# Processing Record 30 of Set 9 | sinnamary
# Processing Record 31 of Set 9 | vila
# Processing Record 32 of Set 9 | miles city
# Processing Record 33 of Set 9 | hasaki
# Processing Record 34 of Set 9 | hirara
# Processing Record 35 of Set 9 | udachnyy
# Processing Record 36 of Set 9 | samdari
# Processing Record 37 of Set 9 | fairbanks
# Processing Record 38 of Set 9 | khon buri
# Processing Record 39 of Set 9 | dunedin
# Processing Record 40 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 9 | clyde river
# Processing Record 42 of Set 9 | mehran
# Processing Record 43 of Set 9 | mayo
# Processing Record 44 of Set 9 | inuvik
# Processing Record 45 of Set 9 | sitka
# Processing Record 46 of Set 9 | dalbandin
# Processing Record 47 of Set 9 | mozarlandia
# Processing Record 48 of Set 9 | villa maria
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | los chiles
# Processing Record 1 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 2 of Set 10 | tateyama
# Processing Record 3 of Set 10 | kruisfontein
# Processing Record 4 of Set 10 | saint anthony
# Processing Record 5 of Set 10 | sumbe
# Processing Record 6 of Set 10 | yeppoon
# Processing Record 7 of Set 10 | kununurra
# Processing Record 8 of Set 10 | lumberton
# Processing Record 9 of Set 10 | isangel
# Processing Record 10 of Set 10 | ilulissat
# Processing Record 11 of Set 10 | pine bluff
# Processing Record 12 of Set 10 | yelatma
# Processing Record 13 of Set 10 | donzdorf
# Processing Record 14 of Set 10 | bambous virieux
# Processing Record 15 of Set 10 | aswan
# Processing Record 16 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 10 | sioux lookout
# Processing Record 18 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 19 of Set 10 | wamba
# Processing Record 20 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 10 | vilhena
# Processing Record 22 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 10 | helong
# Processing Record 25 of Set 10 | kautokeino
# Processing Record 26 of Set 10 | agadez
# Processing Record 27 of Set 10 | chistogorskiy
# Processing Record 28 of Set 10 | broome
# Processing Record 29 of Set 10 | itarema
# Processing Record 30 of Set 10 | terrace bay
# Processing Record 31 of Set 10 | dindori
# Processing Record 32 of Set 10 | mount gambier
# Processing Record 33 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 10 | aneho
# Processing Record 35 of Set 10 | mbandaka
# Processing Record 36 of Set 10 | del rio
# Processing Record 37 of Set 10 | denpasar
# Processing Record 38 of Set 10 | cururupu
# Processing Record 39 of Set 10 | kalmunai
# Processing Record 40 of Set 10 | san patricio
# Processing Record 41 of Set 10 | sabha
# Processing Record 42 of Set 10 | briancon
# Processing Record 43 of Set 10 | akyab
# Processing Record 44 of Set 10 | bullhead city
# Processing Record 45 of Set 10 | santana
# Processing Record 46 of Set 10 | bogotol
# Processing Record 47 of Set 10 | kaeo
# Processing Record 48 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 10 | yarada
# Processing Record 50 of Set 10 | bongandanga
# Processing Record 1 of Set 11 | medicine hat
# Processing Record 2 of Set 11 | takaungu
# Processing Record 3 of Set 11 | saint-augustin
# Processing Record 4 of Set 11 | ixtapa
# Processing Record 5 of Set 11 | bouna
# Processing Record 6 of Set 11 | bowen
# Processing Record 7 of Set 11 | virginia beach
# Processing Record 8 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 11 | astana
# Processing Record 10 of Set 11 | cabudare
# Processing Record 11 of Set 11 | noumea
# Processing Record 12 of Set 11 | ivanava
# Processing Record 13 of Set 11 | mamlyutka
# Processing Record 14 of Set 11 | changping
# Processing Record 15 of Set 11 | lasa
# Processing Record 16 of Set 11 | vitim
# Processing Record 17 of Set 11 | colac
# Processing Record 18 of Set 11 | itarantim
# Processing Record 19 of Set 11 | kedarnath
# City not found. Skipping...
# Processing Record 20 of Set 11 | pascagoula
# Processing Record 21 of Set 11 | santa lucia
# Processing Record 22 of Set 11 | skagen
# Processing Record 23 of Set 11 | omboue
# Processing Record 24 of Set 11 | beloha
# Processing Record 25 of Set 11 | namibe
# Processing Record 26 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 11 | edd
# Processing Record 28 of Set 11 | wuwei
# Processing Record 29 of Set 11 | bolobo
# Processing Record 30 of Set 11 | turinsk
# Processing Record 31 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 11 | kudat
# Processing Record 33 of Set 11 | ginir
# Processing Record 34 of Set 11 | dingle
# Processing Record 35 of Set 11 | ilebo
# Processing Record 36 of Set 11 | erenhot
# Processing Record 37 of Set 11 | arlit
# Processing Record 38 of Set 11 | bras-panon
# Processing Record 39 of Set 11 | puerto madero
# Processing Record 40 of Set 11 | tsumeb
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | milkovo
# Processing Record 43 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 44 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 11 | kirovsk
# Processing Record 46 of Set 11 | kungsbacka
# Processing Record 47 of Set 11 | touros
# Processing Record 48 of Set 11 | berlevag
# Processing Record 49 of Set 11 | havoysund
# Processing Record 50 of Set 11 | labuhan
# Processing Record 1 of Set 12 | melfi
# Processing Record 2 of Set 12 | prigorodnyy
# Processing Record 3 of Set 12 | challapata
# Processing Record 4 of Set 12 | la asuncion
# Processing Record 5 of Set 12 | gerede
# Processing Record 6 of Set 12 | surt
# Processing Record 7 of Set 12 | tigil
# Processing Record 8 of Set 12 | mago
# Processing Record 9 of Set 12 | ayagoz
# Processing Record 10 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 12 | mogadishu
# Processing Record 12 of Set 12 | sevlievo
# Processing Record 13 of Set 12 | charcas
# Processing Record 14 of Set 12 | marzuq
# Processing Record 15 of Set 12 | chebenki
# Processing Record 16 of Set 12 | cayenne
# Processing Record 17 of Set 12 | harper
# Processing Record 18 of Set 12 | gizo
# Processing Record 19 of Set 12 | angola
# Processing Record 20 of Set 12 | samarai
# Processing Record 21 of Set 12 | pljevlja
# Processing Record 22 of Set 12 | pahrump
# Processing Record 23 of Set 12 | guarapari
# Processing Record 24 of Set 12 | romans-sur-isere
# Processing Record 25 of Set 12 | acari
# Processing Record 26 of Set 12 | manasa
# Processing Record 27 of Set 12 | port hawkesbury
# Processing Record 28 of Set 12 | atlantic city
# Processing Record 29 of Set 12 | taucha
# Processing Record 30 of Set 12 | sakakah
# Processing Record 31 of Set 12 | alofi
# Processing Record 32 of Set 12 | araouane
# Processing Record 33 of Set 12 | mundo nuevo
# Processing Record 34 of Set 12 | katsuura
# Processing Record 35 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 12 | saint-pierre
# Processing Record 37 of Set 12 | dubbo
# Processing Record 38 of Set 12 | saint pete beach
# Processing Record 39 of Set 12 | gold coast
# Processing Record 40 of Set 12 | port hedland
# Processing Record 41 of Set 12 | oka
# Processing Record 42 of Set 12 | adelanto
# Processing Record 43 of Set 12 | frutigen
# Processing Record 44 of Set 12 | jalingo
# Processing Record 45 of Set 12 | manzanillo
# Processing Record 46 of Set 12 | cockburn town
# Processing Record 47 of Set 12 | champerico
# Processing Record 48 of Set 12 | wajima
# Processing Record 49 of Set 12 | illapel
# Processing Record 50 of Set 12 | manaus
# Processing Record 1 of Set 13 | dzhebariki-khaya
# Processing Record 2 of Set 13 | ishigaki
# Processing Record 3 of Set 13 | oktyabrskiy
# Processing Record 4 of Set 13 | havelock
# Processing Record 5 of Set 13 | chipata
# Processing Record 6 of Set 13 | sterling
# Processing Record 7 of Set 13 | banda aceh
# Processing Record 8 of Set 13 | camocim
# Processing Record 9 of Set 13 | marienburg
# Processing Record 10 of Set 13 | santa rosalia
# Processing Record 11 of Set 13 | cedar city
# Processing Record 12 of Set 13 | kathmandu
# Processing Record 13 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 14 of Set 13 | sao miguel do araguaia
# Processing Record 15 of Set 13 | chicama
# Processing Record 16 of Set 13 | lermontovka
# Processing Record 17 of Set 13 | palana
# Processing Record 18 of Set 13 | rosetta
# Processing Record 19 of Set 13 | wencheng
# Processing Record 20 of Set 13 | westport
# Processing Record 21 of Set 13 | nyurba
# Processing Record 22 of Set 13 | luau
# Processing Record 23 of Set 13 | benguela
# Processing Record 24 of Set 13 | tairua
# Processing Record 25 of Set 13 | aksu
# Processing Record 26 of Set 13 | hun
# Processing Record 27 of Set 13 | mehamn
# Processing Record 28 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 13 | cherskiy
# Processing Record 30 of Set 13 | guiglo
# Processing Record 31 of Set 13 | gat
# Processing Record 32 of Set 13 | caravelas
# Processing Record 33 of Set 13 | inta
# Processing Record 34 of Set 13 | gossaigaon
# Processing Record 35 of Set 13 | talcahuano
# Processing Record 36 of Set 13 | kashi
# Processing Record 37 of Set 13 | la sarre
# Processing Record 38 of Set 13 | soyo
# Processing Record 39 of Set 13 | the valley
# Processing Record 40 of Set 13 | latung
# Processing Record 41 of Set 13 | goderich
# Processing Record 42 of Set 13 | sergach
# Processing Record 43 of Set 13 | nouakchott
# Processing Record 44 of Set 13 | solnechnyy
# Processing Record 45 of Set 13 | sistranda
# Processing Record 46 of Set 13 | paamiut
# Processing Record 47 of Set 13 | raudeberg
# Processing Record 48 of Set 13 | nemuro
# Processing Record 49 of Set 13 | rafai
# Processing Record 50 of Set 13 | karpogory
# Processing Record 1 of Set 14 | ambrolauri
# Processing Record 2 of Set 14 | bom jardim
# Processing Record 3 of Set 14 | quelimane
# Processing Record 4 of Set 14 | batemans bay
# Processing Record 5 of Set 14 | kaluga
# Processing Record 6 of Set 14 | nantucket
# Processing Record 7 of Set 14 | kosonsoy
# Processing Record 8 of Set 14 | taybad
# Processing Record 9 of Set 14 | narrabri
# Processing Record 10 of Set 14 | nevel
# Processing Record 11 of Set 14 | kokstad
# Processing Record 12 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 14 | bandiagara
# Processing Record 14 of Set 14 | aktau
# Processing Record 15 of Set 14 | ponta delgada
# Processing Record 16 of Set 14 | kaniama
# Processing Record 17 of Set 14 | fort nelson
# Processing Record 18 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 19 of Set 14 | laives
# Processing Record 20 of Set 14 | fereydun kenar
# Processing Record 21 of Set 14 | novomykolayivka
# Processing Record 22 of Set 14 | taoudenni
# Processing Record 23 of Set 14 | rongcheng
# Processing Record 24 of Set 14 | chifeng
# Processing Record 25 of Set 14 | tezpur
# Processing Record 26 of Set 14 | rottingdean
# Processing Record 27 of Set 14 | churapcha
# Processing Record 28 of Set 14 | tacuarembo
# Processing Record 29 of Set 14 | axim
# Processing Record 30 of Set 14 | bozoum
# Processing Record 31 of Set 14 | pevek
# Processing Record 32 of Set 14 | montemor-o-novo
# Processing Record 33 of Set 14 | shar
# Processing Record 34 of Set 14 | bereda
# Processing Record 35 of Set 14 | mahibadhoo
# Processing Record 36 of Set 14 | coihaique
# Processing Record 37 of Set 14 | bandarbeyla
# Processing Record 38 of Set 14 | manta
# Processing Record 39 of Set 14 | sorong
# Processing Record 40 of Set 14 | bose
# Processing Record 41 of Set 14 | bonthe
# Processing Record 42 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 43 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 14 | nerchinskiy zavod
# Processing Record 45 of Set 14 | rostovka
# Processing Record 46 of Set 14 | umm lajj
# Processing Record 47 of Set 14 | muzhi
# Processing Record 48 of Set 14 | kaspiysk
# Processing Record 49 of Set 14 | uyuni
# Processing Record 50 of Set 14 | cochrane
# Processing Record 1 of Set 15 | qandala
# Processing Record 2 of Set 15 | yulara
# Processing Record 3 of Set 15 | wasilla
# Processing Record 4 of Set 15 | newburn
# Processing Record 5 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 15 | dillon
# Processing Record 7 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 15 | miguel alves
# Processing Record 9 of Set 15 | margate
# Processing Record 10 of Set 15 | sechura
# Processing Record 11 of Set 15 | eregli
# Processing Record 12 of Set 15 | grand gaube
# Processing Record 13 of Set 15 | zhongshu
# Processing Record 14 of Set 15 | sawakin
# Processing Record 15 of Set 15 | la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 655

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mnogovershinnyy  53.9353  139.9242     24.26        76          83
# 1         Luderitz -26.6481   15.1594     55.87        84          25
# 2           Hobart -42.8794  147.3294     63.23        57          20
# 3          Ushuaia -54.8000  -68.3000     40.66        70           0
# 4             Sola -13.8833  167.5500     80.47        77         100
# 5          Rikitea -23.1203 -134.9692     74.46        87          98
# 6         Victoria  22.2855  114.1577     82.18        73          66
# 7             Hilo  19.7297 -155.0900     76.73        76         100
# 8     Ponta Do Sol  32.6667  -17.1000     67.71        80          34
# 9        Upernavik  72.7868  -56.1549     10.89        82          95
#
#    Wind Speed Country   Current Description
# 0        8.52      RU         broken clouds
# 1        4.43      NA      scattered clouds
# 2       14.97      AU            few clouds
# 3       10.36      AR             clear sky
# 4        9.15      VU  heavy intensity rain
# 5       15.28      PF       overcast clouds
# 6        5.01      HK         broken clouds
# 7       13.80      US       overcast clouds
# 8        2.89      PT      scattered clouds
# 9        6.89      GL       overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity',
                   'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mnogovershinnyy      RU  53.9353  139.9242     24.26        76          83
# 1         Luderitz      NA -26.6481   15.1594     55.87        84          25
# 2           Hobart      AU -42.8794  147.3294     63.23        57          20
# 3          Ushuaia      AR -54.8000  -68.3000     40.66        70           0
# 4             Sola      VU -13.8833  167.5500     80.47        77         100
# 5          Rikitea      PF -23.1203 -134.9692     74.46        87          98
# 6         Victoria      HK  22.2855  114.1577     82.18        73          66
# 7             Hilo      US  19.7297 -155.0900     76.73        76         100
# 8     Ponta Do Sol      PT  32.6667  -17.1000     67.71        80          34
# 9        Upernavik      GL  72.7868  -56.1549     10.89        82          95
#
#    Wind Speed   Current Description
# 0        8.52         broken clouds
# 1        4.43      scattered clouds
# 2       14.97            few clouds
# 3       10.36             clear sky
# 4        9.15  heavy intensity rain
# 5       15.28       overcast clouds
# 6        5.01         broken clouds
# 7       13.80       overcast clouds
# 8        2.89      scattered clouds
# 9        6.89       overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label='City_ID')
